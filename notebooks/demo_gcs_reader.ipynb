# %% [markdown]
# # Classroom demo: `read_csv_from_gcs`
#
# `src/gcs_reader.py` is unchanged. This notebook **calls** the production function.
#
# Open from the **repo root**. Use Application Default Credentials (`gcloud auth application-default login`).

# %%
import logging
from google.cloud import storage
from src.gcs_reader import read_csv_from_gcs

logging.basicConfig(level=logging.INFO, format="%(levelname)s %(message)s")
logger = logging.getLogger("gcs_reader_demo")
client = storage.Client()

frame = read_csv_from_gcs(
    "travel-incoming-gcp-evening-batch-501811",
    "incoming/employee_travel_20260907.csv",
    client,
    logger,
)
display(frame)
